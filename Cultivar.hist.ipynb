# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/My Drive/Sorghom/"

# %%
import pandas as pd

ds = pd.read_csv(path + "train_cultivar_mapping.csv")

# %%
ds
# Out:
#                               image   cultivar
# 0      2017-06-16__12-24-20-930.png  PI_257599
# 1      2017-06-02__16-48-57-866.png  PI_154987
# 2      2017-06-12__13-18-07-707.png   PI_92270
# 3      2017-06-22__13-18-06-841.png  PI_152651
# 4      2017-06-26__12-56-48-642.png  PI_176766
# ...                             ...        ...
# 22189  2017-06-16__12-27-16-266.png  PI_170787
# 22190  2017-06-28__11-19-57-454.png  PI_156393
# 22191  2017-06-28__10-20-32-417.png  PI_152923
# 22192  2017-06-28__12-47-02-714.png  PI_257599
# 22193  2017-06-04__13-12-56-053.png  PI_196586
#
# [22194 rows x 2 columns]

# %%
ds.value_counts("cultivar")
# Out:
# cultivar
# PI_156393    298
# PI_155760    282
# PI_157030    272
# PI_329299    269
# PI_152771    262
#             ...
# PI_152816    136
# PI_181080    136
# PI_152971    135
# PI_213900    135
# PI_257600    134
# Length: 100, dtype: int64

# %%
ds.value_counts("cultivar").plot(kind ='bar')
# Out:
# <AxesSubplot:xlabel='cultivar'>

# %%
ds.value_counts("cultivar").hist()
# Out:
# <AxesSubplot:>

# %%
path = "/content/drive/My Drive/Sorghom/train_images/2017-06-30__13-10-59-626.png"

# %%
import matplotlib.pyplot as plt

# %%
x = plt.imread(path)

# %%
x
# Out:
# array([[[0.8392157 , 0.84313726, 0.73333335],
#         [0.78039217, 0.827451  , 0.6431373 ],
#         [0.6627451 , 0.7529412 , 0.56078434],
#         ...,
#         [0.42745098, 0.39215687, 0.25882354],
#         [0.4117647 , 0.3882353 , 0.25882354],
#         [0.30980393, 0.40392157, 0.34117648]],
#
#        [[0.81960785, 0.8901961 , 0.78431374],
#         [0.8784314 , 0.90588236, 0.7294118 ],
#         [0.87058824, 0.85882354, 0.61960787],
#         ...,
#         [0.3529412 , 0.40392157, 0.33333334],
#         [0.36078432, 0.40392157, 0.3254902 ],
#         [0.2784314 , 0.3882353 , 0.41960785]],
#
#        [[0.84705883, 0.7137255 , 0.4745098 ],
#         [0.91764706, 0.827451  , 0.5294118 ],
#         [0.972549  , 0.9098039 , 0.5764706 ],
#         ...,
#         [0.35686275, 0.4117647 , 0.3254902 ],
#         [0.35686275, 0.40784314, 0.33333334],
#         [0.27450982, 0.40392157, 0.41960785]],
#
#        ...,
#
#        [[0.43137255, 0.5137255 , 0.34117648],
# ...

# %%
dict = ["name1":10, "name2":12 , ...]

# %%
plt.imshow(x)
