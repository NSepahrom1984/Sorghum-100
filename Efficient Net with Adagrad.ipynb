# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import os
import shutil
from keras.layers import Dense, GlobalAveragePooling2D, Input
from keras.models import load_model

# %%
path  = "C:\\Users\\16395\\Desktop\\Sorghom\\"

# %%
train_df = pd.read_csv(path +'train_cultivar_mapping.csv')
trpath = "C:\\Users\\16395\\Desktop\\Sorghom\\"
train_df.dropna()
# Out:
#                               image   cultivar
# 0      2017-06-16__12-24-20-930.png  PI_257599
# 1      2017-06-02__16-48-57-866.png  PI_154987
# 2      2017-06-12__13-18-07-707.png   PI_92270
# 3      2017-06-22__13-18-06-841.png  PI_152651
# 4      2017-06-26__12-56-48-642.png  PI_176766
# ...                             ...        ...
# 22189  2017-06-16__12-27-16-266.png  PI_170787
# 22190  2017-06-28__11-19-57-454.png  PI_156393
# 22191  2017-06-28__10-20-32-417.png  PI_152923
# 22192  2017-06-28__12-47-02-714.png  PI_257599
# 22193  2017-06-04__13-12-56-053.png  PI_196586
#
# [22193 rows x 2 columns]

# %%
IMG_SIZE = 256
BATCH_SIZE = 8

# %%
train_df['cultivar']=train_df['cultivar'].astype(str)

# %%
train_df
# Out:
#                               image   cultivar
# 0      2017-06-16__12-24-20-930.png  PI_257599
# 1      2017-06-02__16-48-57-866.png  PI_154987
# 2      2017-06-12__13-18-07-707.png   PI_92270
# 3      2017-06-22__13-18-06-841.png  PI_152651
# 4      2017-06-26__12-56-48-642.png  PI_176766
# ...                             ...        ...
# 22189  2017-06-16__12-27-16-266.png  PI_170787
# 22190  2017-06-28__11-19-57-454.png  PI_156393
# 22191  2017-06-28__10-20-32-417.png  PI_152923
# 22192  2017-06-28__12-47-02-714.png  PI_257599
# 22193  2017-06-04__13-12-56-053.png  PI_196586
#
# [22194 rows x 2 columns]

# %%
# Set paths and split ratio
data_path = "C:\\Users\\16395\\Desktop\\Sorghom\\"
csv_path =  "C:\\Users\\16395\\Desktop\\Sorghom\\train_cultivar_mapping.csv"
split_ratio = 0.2

# Load csv file
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=split_ratio, random_state=42)

# %%
train_df['cultivar']=train_df['cultivar'].astype(str)
val_df['cultivar']=val_df['cultivar'].astype(str)

# %%
train_df.count()
data_path = "C:\\Users\\16395\\Desktop\\Sorghom\\train_images"
csv_path =  "C:\\Users\\16395\\Desktop\\Sorghom\\train_cultivar_mapping.csv"
split_ratio = 0.2

# Load csv file
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=split_ratio, random_state=42)

# %%
val_df.count()
# Out:
# image       4439
# cultivar    4439
# dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=path + 'train_images',
    x_col='image',
    y_col='cultivar',
    class_mode='sparse',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=path + 'train_images',
    x_col='image',
    y_col='cultivar',
    class_mode='sparse',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 17754 validated image filenames belonging to 100 classes.
# C:\Users\16395\anaconda3\lib\site-packages\keras\preprocessing\image.py:1139: UserWarning: Found 1 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(
# Found 4439 validated image filenames belonging to 100 classes.

# %%
base_model = keras.applications.EfficientNetB4(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# %%
base_model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x2a9169ee070>,
#  <keras.layers.preprocessing.image_preprocessing.Rescaling at 0x2a9169eeee0>,
#  <keras.layers.preprocessing.normalization.Normalization at 0x2a9161f7a90>,
#  <keras.layers.preprocessing.image_preprocessing.Rescaling at 0x2a9161f7c40>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x2a915d50c10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91641bc10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a915d50e50>,
#  <keras.layers.core.activation.Activation at 0x2a915d50bb0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9164c6d90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9164c6eb0>,
#  <keras.layers.core.activation.Activation at 0x2a916528c40>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91657d160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91657de80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916574280>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916550ee0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a916585580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916635eb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9166399d0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916639dc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916645640>,
#  <keras.layers.core.activation.Activation at 0x2a916645520>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a916645790>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91664e460>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91665a1c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91665a130>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91665a1f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916668880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916668910>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91666fa90>,
#  <keras.layers.merging.add.Add at 0x2a916668400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91666f400>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9166b30d0>,
#  <keras.layers.core.activation.Activation at 0x2a9163cf6a0>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x2a9166b3430>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a91664e100>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916639640>,
#  <keras.layers.core.activation.Activation at 0x2a916528bb0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a9163bb400>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a9163c2a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9163c2580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9163c2400>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9166c8a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9166beac0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9166be700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9166dd1c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9166dd310>,
#  <keras.layers.core.activation.Activation at 0x2a9166dd760>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9166ea880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9166e55b0>,
#  <keras.layers.core.activation.Activation at 0x2a9166e5940>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91672b490>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a9166d6400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916730bb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916730c40>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9167292b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9167290d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916729c40>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a916748400>,
#  <keras.layers.merging.add.Add at 0x2a9166efca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91674e370>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91674e490>,
#  <keras.layers.core.activation.Activation at 0x2a91674ed30>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916757520>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9169a38b0>,
#  <keras.layers.core.activation.Activation at 0x2a9169a3880>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a9169a9910>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a9169b0a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9169b0e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9169be880>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9169c5910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9169c5fa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9169be8b0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a9166e5310>,
#  <keras.layers.merging.add.Add at 0x2a91674e7c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9166d0310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9169a96a0>,
#  <keras.layers.core.activation.Activation at 0x2a9169b6370>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9169a3130>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9169d3eb0>,
#  <keras.layers.core.activation.Activation at 0x2a9169d3e80>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a9169d5f40>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a9169d9310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9169d9df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9169d9d60>,
#  <keras.layers.merging.multiply.Multiply at 0x2a916b29f40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b31520>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b315b0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a916b36730>,
#  <keras.layers.merging.add.Add at 0x2a916b31a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b36f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b41430>,
#  <keras.layers.core.activation.Activation at 0x2a916b52400>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x2a916b52490>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916b45d00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b5a910>,
#  <keras.layers.core.activation.Activation at 0x2a916b5a8e0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a916b5a550>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a916b668e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b70400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b70370>,
#  <keras.layers.merging.multiply.Multiply at 0x2a916b70a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b7cac0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b86610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b86a30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b92a90>,
#  <keras.layers.core.activation.Activation at 0x2a916b92d30>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916b86820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b9fd60>,
#  <keras.layers.core.activation.Activation at 0x2a916b9fd30>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a916b706d0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a916b3d5e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b60820>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b60fa0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9169d8c10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91674e280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b52bb0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a916bdb9d0>,
#  <keras.layers.merging.add.Add at 0x2a916bdb640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916bdd0d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916bdf730>,
#  <keras.layers.core.activation.Activation at 0x2a916b92430>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916bd7190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916be9a90>,
#  <keras.layers.core.activation.Activation at 0x2a916bee490>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a916bee4c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a916bf5be0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916bfb9d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916bfb940>,
#  <keras.layers.merging.multiply.Multiply at 0x2a916bfbb20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916c0bd00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cc72220>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cc7c340>,
#  <keras.layers.merging.add.Add at 0x2a91cc80790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cc80220>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cc801c0>,
#  <keras.layers.core.activation.Activation at 0x2a91cc8f580>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a91cc8fe80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cc96c10>,
#  <keras.layers.core.activation.Activation at 0x2a91cc9d610>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91cc9d460>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91cca4df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cca9b50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cca9ac0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91cca95e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91ccc2250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91ccc22e0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cca47f0>,
#  <keras.layers.merging.add.Add at 0x2a91ccc2d30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916c0bc10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cc875e0>,
#  <keras.layers.core.activation.Activation at 0x2a91cc968b0>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x2a916748580>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9166b3640>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b86f10>,
#  <keras.layers.core.activation.Activation at 0x2a91cc7ceb0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91ccca430>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91ccca760>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cccaeb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916be24c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a916bd7370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916bdbcd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cccd4f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91ccc9460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91ccd8160>,
#  <keras.layers.core.activation.Activation at 0x2a91cce2fd0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a91ccd22b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cce2970>,
#  <keras.layers.core.activation.Activation at 0x2a91ccd2c70>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91ccefac0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91ccef5e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91ccd81c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd3da00>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91ccc9eb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cccdfa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cd54d60>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cd547f0>,
#  <keras.layers.merging.add.Add at 0x2a91ccefc10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd5b670>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cd62e20>,
#  <keras.layers.core.activation.Activation at 0x2a91cd49f10>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a91cd5b880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cd5b1f0>,
#  <keras.layers.core.activation.Activation at 0x2a91cd3db80>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91cd71fd0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91cd625e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd80d60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd7a520>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91cd6b430>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cceff70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cd80be0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cceffd0>,
#  <keras.layers.merging.add.Add at 0x2a91ccd84c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd62280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cd37df0>,
#  <keras.layers.core.activation.Activation at 0x2a91cd37fa0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a91cd62310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cccaf70>,
#  <keras.layers.core.activation.Activation at 0x2a91cccad90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91cd8fe20>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91cd7a940>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd9c940>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd8b280>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91cd6b250>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd80bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cd9cd90>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cdbfc10>,
#  <keras.layers.merging.add.Add at 0x2a91cd8bf10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd8b550>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cd96d30>,
#  <keras.layers.core.activation.Activation at 0x2a91cd96700>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a91cdc6bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cdc6520>,
#  <keras.layers.core.activation.Activation at 0x2a91cdbff10>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a91cddb790>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91cddbf70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdbfe20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cde6e80>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91cde1cd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cda4df0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cde6820>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cde6eb0>,
#  <keras.layers.merging.add.Add at 0x2a91cddb9d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdbff40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9288fcc40>,
#  <keras.layers.core.activation.Activation at 0x2a9288eb760>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9288f6ee0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92890b910>,
#  <keras.layers.core.activation.Activation at 0x2a9288fc970>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a92890be20>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a91cde60d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdbf340>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdbf0d0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91cda4400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cde6be0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cce6f10>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cdd0760>,
#  <keras.layers.merging.add.Add at 0x2a928912d90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9288f6f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cce6640>,
#  <keras.layers.core.activation.Activation at 0x2a91cd37cd0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a928919460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928922dc0>,
#  <keras.layers.core.activation.Activation at 0x2a928919370>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a928925c40>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a9288f6280>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289387c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928922f70>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91cd96b80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928912610>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928949df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdb83a0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928949e20>,
#  <keras.layers.core.activation.Activation at 0x2a92893f6a0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9289612e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928953e20>,
#  <keras.layers.core.activation.Activation at 0x2a92895a940>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a928973160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92892eac0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928973d60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92895ac70>,
#  <keras.layers.merging.multiply.Multiply at 0x2a928949310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92893fc10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92897a970>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a928997eb0>,
#  <keras.layers.merging.add.Add at 0x2a9289195e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289976d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9289223a0>,
#  <keras.layers.core.activation.Activation at 0x2a92899c2b0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a92899ceb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92897a6a0>,
#  <keras.layers.core.activation.Activation at 0x2a92899c1f0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a9289194c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92895a490>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289126a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdbf1c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a91cdd0520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928938dc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9289b02e0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a9289b3f10>,
#  <keras.layers.merging.add.Add at 0x2a928953d90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289bb820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92898f940>,
#  <keras.layers.core.activation.Activation at 0x2a9289c0fd0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9289b3940>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9289bbca0>,
#  <keras.layers.core.activation.Activation at 0x2a9289c0b50>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a9289cad60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a928912250>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289dbd30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289dbee0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a928984f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289a6e20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9289e16d0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a9289f5bb0>,
#  <keras.layers.merging.add.Add at 0x2a9289cf1c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289c0430>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928a07a60>,
#  <keras.layers.core.activation.Activation at 0x2a928a174f0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a928a17550>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9289ca2e0>,
#  <keras.layers.core.activation.Activation at 0x2a928a1d310>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a928a07dc0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a928a1dbb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289e1dc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a1dd90>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9289e1100>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289e1e20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928a33970>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a928a43e80>,
#  <keras.layers.merging.add.Add at 0x2a928a43fd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a3c850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9289e1700>,
#  <keras.layers.core.activation.Activation at 0x2a9289e1190>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a9289e1fa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9289f59d0>,
#  <keras.layers.core.activation.Activation at 0x2a928984fa0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a92893f4c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a9289b3f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a1d130>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289c04c0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9289c0ca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a33190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928a50250>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a928a56f10>,
#  <keras.layers.merging.add.Add at 0x2a92892e9d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a17af0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928a5f130>,
#  <keras.layers.core.activation.Activation at 0x2a928a5f1c0>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x2a928a73640>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916b862e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928a6e700>,
#  <keras.layers.core.activation.Activation at 0x2a9289cff70>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a928a56250>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a928a88f10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a7cfd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a4cd60>,
#  <keras.layers.merging.multiply.Multiply at 0x2a928a62610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a50940>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928a97880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a887f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b152f70>,
#  <keras.layers.core.activation.Activation at 0x2a928a97520>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a92b16bb50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b175a60>,
#  <keras.layers.core.activation.Activation at 0x2a92b15f6a0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a92b17c940>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92b17c7f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b184df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b184f10>,
#  <keras.layers.merging.multiply.Multiply at 0x2a92b15b130>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a7c790>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b1849d0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a9289cffa0>,
#  <keras.layers.merging.add.Add at 0x2a928a73370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdbf430>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a928938b20>,
#  <keras.layers.core.activation.Activation at 0x2a928a7c820>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a928a6ed00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b18aac0>,
#  <keras.layers.core.activation.Activation at 0x2a9289b37c0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a928a5f910>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92b1842b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b1a0370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b1a0a30>,
#  <keras.layers.merging.multiply.Multiply at 0x2a92b15bd60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b19b040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b184fd0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a92b18a6d0>,
#  <keras.layers.merging.add.Add at 0x2a928a5fa30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cdbf250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b1a05e0>,
#  <keras.layers.core.activation.Activation at 0x2a92b1a0a60>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a92b19b550>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b1cabe0>,
#  <keras.layers.core.activation.Activation at 0x2a92b1c1880>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a92b1da160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92b19b670>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b1da550>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b1dac70>,
#  <keras.layers.merging.multiply.Multiply at 0x2a92b1a0970>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b1a7190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b1eb880>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a92b1fb4f0>,
#  <keras.layers.merging.add.Add at 0x2a92b1fbee0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92b1f4820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b1a0f10>,
#  <keras.layers.core.activation.Activation at 0x2a92b1f4af0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a92b20af40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b1ebe80>,
#  <keras.layers.core.activation.Activation at 0x2a92b20a2e0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a92b205ee0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92b205910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a914c73ac0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a914bb6040>,
#  <keras.layers.merging.multiply.Multiply at 0x2a914bbe220>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916639ca0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916639700>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a916730d60>,
#  <keras.layers.merging.add.Add at 0x2a916730070>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916744ee0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9167445b0>,
#  <keras.layers.core.activation.Activation at 0x2a9163bbd00>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916645280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9169a9b80>,
#  <keras.layers.core.activation.Activation at 0x2a9169a92b0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a9163c2070>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a916b60610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b52160>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b52280>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9166d0d00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916b754c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9169d9a30>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a91cc96190>,
#  <keras.layers.merging.add.Add at 0x2a91ccb9370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cc7c040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916b45a30>,
#  <keras.layers.core.activation.Activation at 0x2a916bfb7f0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a91cc720d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a91cca4bb0>,
#  <keras.layers.core.activation.Activation at 0x2a916be2820>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a92b1caa60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92b1d25e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289a62b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9289a65b0>,
#  <keras.layers.merging.multiply.Multiply at 0x2a92890b4c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd80820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916bd70d0>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a9169beb80>,
#  <keras.layers.merging.add.Add at 0x2a91666fd00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a916668b20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a916bd74f0>,
#  <keras.layers.core.activation.Activation at 0x2a91cd7a340>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a916bfb5b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a9169befa0>,
#  <keras.layers.core.activation.Activation at 0x2a915d50c70>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a9166d0970>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a9164c6be0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a928a90430>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a91cd37f70>,
#  <keras.layers.merging.multiply.Multiply at 0x2a92b1af700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92eb3f700>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92eb41a30>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a92eb3fbe0>,
#  <keras.layers.merging.add.Add at 0x2a92eb41d00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92eb4a280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92eb4a3a0>,
#  <keras.layers.core.activation.Activation at 0x2a92eb4ac10>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a92eb53ca0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92eb57370>,
#  <keras.layers.core.activation.Activation at 0x2a92eb57a90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a92eb5fee0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a92eb63ca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92eb5fb80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92eb5f910>,
#  <keras.layers.merging.multiply.Multiply at 0x2a92eb78ca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92eb71280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92eb71070>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92eb888b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92eb811f0>,
#  <keras.layers.core.activation.Activation at 0x2a932411100>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x2a92eb682b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a93241cbb0>,
#  <keras.layers.core.activation.Activation at 0x2a93241c970>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x2a93242b880>,
#  <keras.layers.reshaping.reshape.Reshape at 0x2a93242b100>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a93241ca60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a932435670>,
#  <keras.layers.merging.multiply.Multiply at 0x2a9324356a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a92eb88a30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a932422790>,
#  <keras.layers.regularization.dropout.Dropout at 0x2a92eb535b0>,
#  <keras.layers.merging.add.Add at 0x2a92eb78e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2a9164c6d00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x2a92b215700>,
#  <keras.layers.core.activation.Activation at 0x2a92897a370>]

# %%
print(len(base_model.layers))
# Out:
# 475

# %%
inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
output = base_model(inputs)
output = GlobalAveragePooling2D()(output)
output = Dense(100, activation='softmax')(output)

model = keras.Model(inputs, output)

model.summary()

model.compile(loss='sparse_categorical_crossentropy', optimizer='Adagrad', metrics=['accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  efficientnetb4 (Functional)  (None, 8, 8, 1792)       17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 100)               179300
#
# =================================================================
# Total params: 17,853,123
# Trainable params: 17,727,916
# Non-trainable params: 125,207
# _________________________________________________________________

# %%
history = model.fit(train_generator, validation_data=valid_generator, epochs=10)
# Out:
# Epoch 1/10
# 2220/2220 [==============================] - 2521s 1s/step - loss: 4.5674 - accuracy: 0.0237 - val_loss: 4.4661 - val_accuracy: 0.0487
# Epoch 2/10
# 2220/2220 [==============================] - 1575s 709ms/step - loss: 4.3240 - accuracy: 0.0663 - val_loss: 4.0901 - val_accuracy: 0.1009
# Epoch 3/10
# 2220/2220 [==============================] - 1478s 666ms/step - loss: 3.9248 - accuracy: 0.1208 - val_loss: 3.6286 - val_accuracy: 0.1626
# Epoch 4/10
# 2220/2220 [==============================] - 893s 402ms/step - loss: 3.5367 - accuracy: 0.1777 - val_loss: 3.1541 - val_accuracy: 0.2341
# Epoch 5/10
# 2220/2220 [==============================] - 910s 410ms/step - loss: 3.2069 - accuracy: 0.2415 - val_loss: 2.7686 - val_accuracy: 0.3102
# Epoch 6/10
# 2220/2220 [==============================] - 895s 403ms/step - loss: 2.9246 - accuracy: 0.2908 - val_loss: 2.4453 - val_accuracy: 0.3821
# Epoch 7/10
# 2220/2220 [==============================] - 895s 403ms/step - loss: 2.6797 - accuracy: 0.3380 - val_loss: 2.2020 - val_accuracy: 0.4373
# Epoch 8/10
# 2220/2220 [==============================] - 894s 403ms/step - loss: 2.4808 - accuracy: 0.3805 - val_loss: 1.9835 - val_accuracy: 0.4765
# Epoch 9/10
# 2220/2220 [==============================] - 914s 412ms/step - loss: 2.3165 - accuracy: 0.4168 - val_loss: 1.7881 - val_accuracy: 0.5181
# Epoch 10/10
# 2220/2220 [==============================] - 906s 408ms/step - loss: 2.1683 - accuracy: 0.4459 - val_loss: 1.6475 - val_accuracy: 0.5632

# %%
model.fit(train_generator, validation_data=valid_generator, epochs=5)
# Out:
# Epoch 1/5
# 2220/2220 [==============================] - 861s 388ms/step - loss: 2.0529 - accuracy: 0.4703 - val_loss: 1.5318 - val_accuracy: 0.5837
# Epoch 2/5
# 2220/2220 [==============================] - 912s 411ms/step - loss: 1.9492 - accuracy: 0.4974 - val_loss: 1.4228 - val_accuracy: 0.6128
# Epoch 3/5
# 2220/2220 [==============================] - 931s 419ms/step - loss: 1.8504 - accuracy: 0.5204 - val_loss: 1.3350 - val_accuracy: 0.6366
# Epoch 4/5
# 2220/2220 [==============================] - 4093s 2s/step - loss: 1.7750 - accuracy: 0.5354 - val_loss: 1.2564 - val_accuracy: 0.6614
# Epoch 5/5
# 2220/2220 [==============================] - 1501s 676ms/step - loss: 1.6963 - accuracy: 0.5531 - val_loss: 1.1806 - val_accuracy: 0.6758

# %%
model.save("g:/effiecient.h5")

# %%
loaded_model = load_model("g:/effiecient.h5")
