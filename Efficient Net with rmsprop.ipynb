# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import os
import shutil
from keras.layers import Dense, GlobalAveragePooling2D, Input
from keras.models import load_model

# %%
path  = "C:\\Users\\16395\\Desktop\\Sorghom\\"

# %%
train_df = pd.read_csv(path +'train_cultivar_mapping.csv')
trpath = "C:\\Users\\16395\\Desktop\\Sorghom\\"
train_df.dropna()
# Out:
#                               image   cultivar
# 0      2017-06-16__12-24-20-930.png  PI_257599
# 1      2017-06-02__16-48-57-866.png  PI_154987
# 2      2017-06-12__13-18-07-707.png   PI_92270
# 3      2017-06-22__13-18-06-841.png  PI_152651
# 4      2017-06-26__12-56-48-642.png  PI_176766
# ...                             ...        ...
# 22189  2017-06-16__12-27-16-266.png  PI_170787
# 22190  2017-06-28__11-19-57-454.png  PI_156393
# 22191  2017-06-28__10-20-32-417.png  PI_152923
# 22192  2017-06-28__12-47-02-714.png  PI_257599
# 22193  2017-06-04__13-12-56-053.png  PI_196586
#
# [22193 rows x 2 columns]

# %%
IMG_SIZE = 256
BATCH_SIZE = 8

# %%
train_df['cultivar']=train_df['cultivar'].astype(str)

# %%
train_df
# Out:
#                               image   cultivar
# 0      2017-06-16__12-24-20-930.png  PI_257599
# 1      2017-06-02__16-48-57-866.png  PI_154987
# 2      2017-06-12__13-18-07-707.png   PI_92270
# 3      2017-06-22__13-18-06-841.png  PI_152651
# 4      2017-06-26__12-56-48-642.png  PI_176766
# ...                             ...        ...
# 22189  2017-06-16__12-27-16-266.png  PI_170787
# 22190  2017-06-28__11-19-57-454.png  PI_156393
# 22191  2017-06-28__10-20-32-417.png  PI_152923
# 22192  2017-06-28__12-47-02-714.png  PI_257599
# 22193  2017-06-04__13-12-56-053.png  PI_196586
#
# [22194 rows x 2 columns]

# %%
# Set paths and split ratio
data_path = "C:\\Users\\16395\\Desktop\\Sorghom\\"
csv_path =  "C:\\Users\\16395\\Desktop\\Sorghom\\train_cultivar_mapping.csv"
split_ratio = 0.2

# Load csv file
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=split_ratio, random_state=42)

# %%
train_df['cultivar']=train_df['cultivar'].astype(str)
val_df['cultivar']=val_df['cultivar'].astype(str)

# %%
train_df.count()
data_path = "C:\\Users\\16395\\Desktop\\Sorghom\\train_images"
csv_path =  "C:\\Users\\16395\\Desktop\\Sorghom\\train_cultivar_mapping.csv"
split_ratio = 0.2

# Load csv file
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=split_ratio, random_state=42)

# %%
val_df.count()
# Out:
# image       4439
# cultivar    4439
# dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=path + 'train_images',
    x_col='image',
    y_col='cultivar',
    class_mode='sparse',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=path + 'train_images',
    x_col='image',
    y_col='cultivar',
    class_mode='sparse',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 17754 validated image filenames belonging to 100 classes.
# C:\Users\16395\anaconda3\lib\site-packages\keras\preprocessing\image.py:1139: UserWarning: Found 1 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(
# Found 4439 validated image filenames belonging to 100 classes.

# %%
base_model = keras.applications.EfficientNetB4(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# %%
base_model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x189704561c0>,
#  <keras.layers.preprocessing.image_preprocessing.Rescaling at 0x1897e030b50>,
#  <keras.layers.preprocessing.normalization.Normalization at 0x1897e038760>,
#  <keras.layers.preprocessing.image_preprocessing.Rescaling at 0x18970811df0>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x1897db9fd00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1897e25ac10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1897e25ab80>,
#  <keras.layers.core.activation.Activation at 0x1897e25aaf0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911b76d90>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911b76eb0>,
#  <keras.layers.core.activation.Activation at 0x18911bc7c40>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18911bfd160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18911bfde80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911bf2160>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911bcfee0>,
#  <keras.layers.merging.multiply.Multiply at 0x18911c04580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c13eb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c189d0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911c18dc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c22640>,
#  <keras.layers.core.activation.Activation at 0x18911c22520>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18911c22790>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18911c2e6a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c391c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c39130>,
#  <keras.layers.merging.multiply.Multiply at 0x18911c391f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c47880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c47910>,
#  <keras.layers.regularization.dropout.Dropout at 0x18911c4ca90>,
#  <keras.layers.merging.add.Add at 0x18911c47400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c4c400>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c4d0d0>,
#  <keras.layers.core.activation.Activation at 0x1897e20f6a0>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x18911c4d430>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911c2e100>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c18640>,
#  <keras.layers.core.activation.Activation at 0x18911bc7bb0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1897e1fa400>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18911c627c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c62580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c62400>,
#  <keras.layers.merging.multiply.Multiply at 0x18911c68a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c5fac0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c5f700>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c7b1c0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c7b310>,
#  <keras.layers.core.activation.Activation at 0x18911c7b760>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911c88880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c845b0>,
#  <keras.layers.core.activation.Activation at 0x18911c84940>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18911c99490>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18911c76400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c9ebb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c9ec40>,
#  <keras.layers.merging.multiply.Multiply at 0x18911c972b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c970d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911c97c40>,
#  <keras.layers.regularization.dropout.Dropout at 0x18911cb7400>,
#  <keras.layers.merging.add.Add at 0x18911c8dca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911cbb370>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911cbb490>,
#  <keras.layers.core.activation.Activation at 0x18911cbbd30>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911cc5520>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911cd18b0>,
#  <keras.layers.core.activation.Activation at 0x18911cd1880>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18911cd8910>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18911cd9a00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911cd9e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911ced880>,
#  <keras.layers.merging.multiply.Multiply at 0x18911cf5910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911cf5fa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911ced8b0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18911c84310>,
#  <keras.layers.merging.add.Add at 0x18911cbb7c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c6f310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911cd86a0>,
#  <keras.layers.core.activation.Activation at 0x18911ce5370>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911cd1130>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911cffeb0>,
#  <keras.layers.core.activation.Activation at 0x18911cffe80>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18911d03f40>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18911d080d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911d08df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911d08d60>,
#  <keras.layers.merging.multiply.Multiply at 0x18918079f40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18918081520>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189180815b0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18918084730>,
#  <keras.layers.merging.add.Add at 0x18918081a60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18918084f10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18918091430>,
#  <keras.layers.core.activation.Activation at 0x189180a1400>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x189180a1490>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18918094d00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189180aa910>,
#  <keras.layers.core.activation.Activation at 0x189180aa8e0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x189180aa550>,
#  <keras.layers.reshaping.reshape.Reshape at 0x189180b36a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180bf400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180bf370>,
#  <keras.layers.merging.multiply.Multiply at 0x189180bfa00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180ccac0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189180d5610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180d5a30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189180e2a90>,
#  <keras.layers.core.activation.Activation at 0x189180e2d30>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x189180d5820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189180edd60>,
#  <keras.layers.core.activation.Activation at 0x189180edd30>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x189180bf4f0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x1891808b5e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180af820>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180affa0>,
#  <keras.layers.merging.multiply.Multiply at 0x18911d06c10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911cbb280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189180a1bb0>,
#  <keras.layers.regularization.dropout.Dropout at 0x1891952a9d0>,
#  <keras.layers.merging.add.Add at 0x1891952a640>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1891952c0d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1891952e730>,
#  <keras.layers.core.activation.Activation at 0x189180e2430>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18919526190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18919538a90>,
#  <keras.layers.core.activation.Activation at 0x1891953d490>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1891953d4c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18919544be0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1891954c9d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1891954c940>,
#  <keras.layers.merging.multiply.Multiply at 0x1891954cb20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18919559d00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18919cb3220>,
#  <keras.layers.regularization.dropout.Dropout at 0x18919cbb340>,
#  <keras.layers.merging.add.Add at 0x18919cbf790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18919cbf250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18919cbf1c0>,
#  <keras.layers.core.activation.Activation at 0x18919cce580>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18919ccee80>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18919cd5c10>,
#  <keras.layers.core.activation.Activation at 0x18919cdc610>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18919cdc430>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18919ce3df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18919ce8b50>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18919ce8ac0>,
#  <keras.layers.merging.multiply.Multiply at 0x18919ce85e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e21250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e212e0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18919ce37f0>,
#  <keras.layers.merging.add.Add at 0x18920e21d30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18919559c10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18919cc65e0>,
#  <keras.layers.core.activation.Activation at 0x18919cd58b0>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x18911cb7580>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911c4d640>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189180d5f10>,
#  <keras.layers.core.activation.Activation at 0x18919cbbeb0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18920e29430>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18920e29760>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e29eb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189195314c0>,
#  <keras.layers.merging.multiply.Multiply at 0x18919526370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1891952acd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e2c4f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e28460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e36160>,
#  <keras.layers.core.activation.Activation at 0x18920e3efd0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18920e312b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e3e970>,
#  <keras.layers.core.activation.Activation at 0x18920e31c70>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18920e4eac0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18920e4e5e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e361c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e5ea00>,
#  <keras.layers.merging.multiply.Multiply at 0x18920e28eb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e2cfa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e73d60>,
#  <keras.layers.regularization.dropout.Dropout at 0x18920e737f0>,
#  <keras.layers.merging.add.Add at 0x18920e4ec10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e7a670>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e81e20>,
#  <keras.layers.core.activation.Activation at 0x18920e68f10>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18920e7a880>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e7a220>,
#  <keras.layers.core.activation.Activation at 0x18920e5eb80>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18920e8ffd0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18920e815e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e9dd60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e98520>,
#  <keras.layers.merging.multiply.Multiply at 0x18920e8a430>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e4edf0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e9dbe0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18920e4efd0>,
#  <keras.layers.merging.add.Add at 0x18920e364f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e81280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e56df0>,
#  <keras.layers.core.activation.Activation at 0x18920e56fa0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18920e81310>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e29f70>,
#  <keras.layers.core.activation.Activation at 0x18920e29d90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18920eafe20>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18920e98940>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920eb2940>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920eabe80>,
#  <keras.layers.merging.multiply.Multiply at 0x18920e8a250>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e9dbb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920eb2d90>,
#  <keras.layers.regularization.dropout.Dropout at 0x18920edec10>,
#  <keras.layers.merging.add.Add at 0x18920eabee0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920eab550>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920eb5d30>,
#  <keras.layers.core.activation.Activation at 0x18920eb5700>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18920ee5bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920ee54f0>,
#  <keras.layers.core.activation.Activation at 0x18920edef10>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18920ef9790>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18920ef9f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920edee20>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920f05e80>,
#  <keras.layers.merging.multiply.Multiply at 0x18920f01cd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920ec3df0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920f05820>,
#  <keras.layers.regularization.dropout.Dropout at 0x18920f05eb0>,
#  <keras.layers.merging.add.Add at 0x18920ef99d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920edef40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892137bc40>,
#  <keras.layers.core.activation.Activation at 0x1892136a760>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18921374ee0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892138a910>,
#  <keras.layers.core.activation.Activation at 0x1892137b970>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1892138ae20>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18920f050d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920ede340>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920ede0d0>,
#  <keras.layers.merging.multiply.Multiply at 0x18920ec3400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920f05bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e45f10>,
#  <keras.layers.regularization.dropout.Dropout at 0x18920ef0760>,
#  <keras.layers.merging.add.Add at 0x18921391d90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18921374f70>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18920e45640>,
#  <keras.layers.core.activation.Activation at 0x18920e56cd0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18921398460>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927460dc0>,
#  <keras.layers.core.activation.Activation at 0x18921398370>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18927464c40>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18921374280>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274777c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927460f70>,
#  <keras.layers.merging.multiply.Multiply at 0x18920eb5b80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18921391610>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927487df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920ed7520>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927487e20>,
#  <keras.layers.core.activation.Activation at 0x1892747e6a0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x189274a02e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927492e20>,
#  <keras.layers.core.activation.Activation at 0x18927499940>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x189274ae160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x1892746eac0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274aed60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927499c70>,
#  <keras.layers.merging.multiply.Multiply at 0x18927487310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892747ec10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189274b9970>,
#  <keras.layers.regularization.dropout.Dropout at 0x189274d3eb0>,
#  <keras.layers.merging.add.Add at 0x189213985e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274d36d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189274603a0>,
#  <keras.layers.core.activation.Activation at 0x189274dc2b0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x189274dceb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189274b96a0>,
#  <keras.layers.core.activation.Activation at 0x189274dc1f0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x189213984c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18927499490>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189213916a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920ede1c0>,
#  <keras.layers.merging.multiply.Multiply at 0x18920ef0520>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927477dc0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189274ef2e0>,
#  <keras.layers.regularization.dropout.Dropout at 0x189274f0f10>,
#  <keras.layers.merging.add.Add at 0x18927492d90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274f9820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189274ce940>,
#  <keras.layers.core.activation.Activation at 0x189274fefd0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x189274f0940>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189274f9280>,
#  <keras.layers.core.activation.Activation at 0x189274feb50>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18927508d60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18921391250>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927519d30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927519ee0>,
#  <keras.layers.merging.multiply.Multiply at 0x189274c4f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274e3e20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189275206d0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18927534bb0>,
#  <keras.layers.merging.add.Add at 0x1892750e1c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274fe430>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927547a60>,
#  <keras.layers.core.activation.Activation at 0x189275564f0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18927556550>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189275082e0>,
#  <keras.layers.core.activation.Activation at 0x1892755b310>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18927547dc0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x1892755bbb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927520dc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892755bd90>,
#  <keras.layers.merging.multiply.Multiply at 0x18927520100>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927520e20>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927571970>,
#  <keras.layers.regularization.dropout.Dropout at 0x18927583e80>,
#  <keras.layers.merging.add.Add at 0x18927583fd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892757a850>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927520700>,
#  <keras.layers.core.activation.Activation at 0x18927520670>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18927520fa0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189275349d0>,
#  <keras.layers.core.activation.Activation at 0x189274c4fa0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1892747e4c0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x189274f0f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892755b130>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274fe4c0>,
#  <keras.layers.merging.multiply.Multiply at 0x189274feca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927571190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927590250>,
#  <keras.layers.regularization.dropout.Dropout at 0x18927596f10>,
#  <keras.layers.merging.add.Add at 0x1892746e9d0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927556af0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892759f130>,
#  <keras.layers.core.activation.Activation at 0x1892759f1c0>,
#  <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x189275b3640>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x189180d52e0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189275ae700>,
#  <keras.layers.core.activation.Activation at 0x1892750ef70>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18927596250>,
#  <keras.layers.reshaping.reshape.Reshape at 0x189275c8f10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189275bcfd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892758ad60>,
#  <keras.layers.merging.multiply.Multiply at 0x189275a2610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927590940>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189275d8880>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189275c87f0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189275e2f70>,
#  <keras.layers.core.activation.Activation at 0x189275d8520>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x189275fbb50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927606a60>,
#  <keras.layers.core.activation.Activation at 0x189275ef6a0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1892760c940>,
#  <keras.layers.reshaping.reshape.Reshape at 0x1892760c7f0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927614df0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927614f10>,
#  <keras.layers.merging.multiply.Multiply at 0x189275eb130>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189275bc790>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189276149d0>,
#  <keras.layers.regularization.dropout.Dropout at 0x1892750efa0>,
#  <keras.layers.merging.add.Add at 0x189275b3370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920ede430>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927477b20>,
#  <keras.layers.core.activation.Activation at 0x189275bc820>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x189275aed00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892761aac0>,
#  <keras.layers.core.activation.Activation at 0x189274f07c0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1892759f910>,
#  <keras.layers.reshaping.reshape.Reshape at 0x189276142b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892762f370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892762fa30>,
#  <keras.layers.merging.multiply.Multiply at 0x189275ebd60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892762a040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18927614fd0>,
#  <keras.layers.regularization.dropout.Dropout at 0x1892761a6d0>,
#  <keras.layers.merging.add.Add at 0x1892759fa30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920ede250>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892762f5e0>,
#  <keras.layers.core.activation.Activation at 0x1892762fa60>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x1892762a550>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892765abe0>,
#  <keras.layers.core.activation.Activation at 0x18927650880>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18927669160>,
#  <keras.layers.reshaping.reshape.Reshape at 0x1892762a670>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927669550>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927669c70>,
#  <keras.layers.merging.multiply.Multiply at 0x1892762f970>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927636190>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892767a880>,
#  <keras.layers.regularization.dropout.Dropout at 0x1892768b4f0>,
#  <keras.layers.merging.add.Add at 0x1892768bee0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18927684820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892762ff10>,
#  <keras.layers.core.activation.Activation at 0x18927684af0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x1892769af40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x1892767ae80>,
#  <keras.layers.core.activation.Activation at 0x1892769a2e0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18927694ee0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18927694910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1897cac2ac0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1897ca05550>,
#  <keras.layers.merging.multiply.Multiply at 0x1897db9fcd0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911b76bb0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911b762b0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18911c9e100>,
#  <keras.layers.merging.add.Add at 0x18911cc56a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c840d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911cd9250>,
#  <keras.layers.core.activation.Activation at 0x18911cd95b0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18911c13be0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911cd8610>,
#  <keras.layers.core.activation.Activation at 0x18911cd89a0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18918079040>,
#  <keras.layers.reshaping.reshape.Reshape at 0x189180b3610>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180a14c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180a13a0>,
#  <keras.layers.merging.multiply.Multiply at 0x18911d06910>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189180c5040>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911bf25e0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18919cd5160>,
#  <keras.layers.merging.add.Add at 0x18919cd5dc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18919cbbc10>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18918094a30>,
#  <keras.layers.core.activation.Activation at 0x1891954c7f0>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18919cb30d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18919ce3bb0>,
#  <keras.layers.core.activation.Activation at 0x18919531820>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1892765aa60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x189276625e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274e32b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x189274e35b0>,
#  <keras.layers.merging.multiply.Multiply at 0x1892138a4c0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18920e9d820>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189195260d0>,
#  <keras.layers.regularization.dropout.Dropout at 0x18911cedb80>,
#  <keras.layers.merging.add.Add at 0x18911c4cd00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911c47b50>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x189195264f0>,
#  <keras.layers.core.activation.Activation at 0x18920e98340>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x1891954cc40>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18911cf5a00>,
#  <keras.layers.core.activation.Activation at 0x18911c474c0>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x1897e1fad60>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18911bc7eb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892758ad30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1892763e700>,
#  <keras.layers.merging.multiply.Multiply at 0x18920e56f70>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928c9f700>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928ca1a30>,
#  <keras.layers.regularization.dropout.Dropout at 0x18928c9fbe0>,
#  <keras.layers.merging.add.Add at 0x18928ca1d00>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928caa280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928caa3a0>,
#  <keras.layers.core.activation.Activation at 0x18928caac10>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18928cb3ca0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928cb7370>,
#  <keras.layers.core.activation.Activation at 0x18928cb7a90>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18928cbfee0>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18928cc3ca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928cbfb80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928cbf910>,
#  <keras.layers.merging.multiply.Multiply at 0x18928cd7ca0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928cd3280>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928cd3070>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928ce88b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928ce11f0>,
#  <keras.layers.core.activation.Activation at 0x18928cef100>,
#  <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x18928cc82b0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928cfcbb0>,
#  <keras.layers.core.activation.Activation at 0x18928cfc970>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x18928d0a880>,
#  <keras.layers.reshaping.reshape.Reshape at 0x18928d0a100>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928cfca60>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928d15670>,
#  <keras.layers.merging.multiply.Multiply at 0x18928d156a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18928ce8a30>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928d01790>,
#  <keras.layers.regularization.dropout.Dropout at 0x18928cb35b0>,
#  <keras.layers.merging.add.Add at 0x18928cd7e80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x18911b76d00>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x18928c35970>,
#  <keras.layers.core.activation.Activation at 0x189274b9370>]

# %%
print(len(base_model.layers))
# Out:
# 475

# %%
inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
output = base_model(inputs)
output = GlobalAveragePooling2D()(output)
output = Dense(100, activation='softmax')(output)

model = keras.Model(inputs, output)

model.summary()

model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  efficientnetb4 (Functional)  (None, 8, 8, 1792)       17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 100)               179300
#
# =================================================================
# Total params: 17,853,123
# Trainable params: 17,727,916
# Non-trainable params: 125,207
# _________________________________________________________________

# %%
history = model.fit(train_generator, validation_data=valid_generator, epochs=10)
# Out:
# Epoch 1/10
# 2220/2220 [==============================] - 1596s 695ms/step - loss: 3.4527 - accuracy: 0.1778 - val_loss: 2.4733 - val_accuracy: 0.3773
# Epoch 2/10
# 2220/2220 [==============================] - 1175s 529ms/step - loss: 2.1582 - accuracy: 0.4194 - val_loss: 1.7817 - val_accuracy: 0.5373
# Epoch 3/10
# 2220/2220 [==============================] - 11282s 5s/step - loss: 1.6245 - accuracy: 0.5454 - val_loss: 1.3502 - val_accuracy: 0.6321
# Epoch 4/10
# 2220/2220 [==============================] - 960s 433ms/step - loss: 1.3020 - accuracy: 0.6265 - val_loss: 1.7184 - val_accuracy: 0.5983
# Epoch 5/10
# 2220/2220 [==============================] - 1080s 486ms/step - loss: 1.0929 - accuracy: 0.6807 - val_loss: 1.2949 - val_accuracy: 0.6625
# Epoch 6/10
# 2220/2220 [==============================] - 11652s 5s/step - loss: 0.9360 - accuracy: 0.7243 - val_loss: 1.1589 - val_accuracy: 0.6970
# Epoch 7/10
# 2220/2220 [==============================] - 1008s 454ms/step - loss: 0.8279 - accuracy: 0.7499 - val_loss: 0.9192 - val_accuracy: 0.7475
# Epoch 8/10
# 2220/2220 [==============================] - 939s 423ms/step - loss: 0.7474 - accuracy: 0.7734 - val_loss: 0.7724 - val_accuracy: 0.7840
# Epoch 9/10
# 2220/2220 [==============================] - 953s 429ms/step - loss: 0.6609 - accuracy: 0.7967 - val_loss: 0.8331 - val_accuracy: 0.7959
# Epoch 10/10
# 2220/2220 [==============================] - 1200s 541ms/step - loss: 0.6053 - accuracy: 0.8168 - val_loss: 0.5222 - val_accuracy: 0.8606

# %%
model.fit(train_generator, validation_data=valid_generator, epochs=5)
# Out:
# Epoch 1/5
# 2220/2220 [==============================] - 1320s 595ms/step - loss: 0.5482 - accuracy: 0.8327 - val_loss: 0.6282 - val_accuracy: 0.8340
# Epoch 2/5
# 2220/2220 [==============================] - 985s 443ms/step - loss: 0.5121 - accuracy: 0.8436 - val_loss: 0.6781 - val_accuracy: 0.8123
# Epoch 3/5
# 2220/2220 [==============================] - 1548s 697ms/step - loss: 0.4847 - accuracy: 0.8474 - val_loss: 0.6789 - val_accuracy: 0.8202
# Epoch 4/5
# 2220/2220 [==============================] - 1762s 794ms/step - loss: 0.4389 - accuracy: 0.8644 - val_loss: 0.9363 - val_accuracy: 0.7747
# Epoch 5/5
# 2220/2220 [==============================] - 1477s 665ms/step - loss: 0.4394 - accuracy: 0.8661 - val_loss: 0.7982 - val_accuracy: 0.8011

# %%
model.save("g:/effiecient.h5")

# %%
loaded_model = load_model("g:/effiecient.
                          h5")
